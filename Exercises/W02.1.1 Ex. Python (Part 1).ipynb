# %% [markdown]
# # Week 2 - Exercises - Python Essentials (Part 1) [codingwatchcity]

# %% [markdown]
# ## Contents
# 1. Data lab notebooks
# 1. Lists
# 1. Dictionaries
# 1. Comprehensions
# 1. Map & filter
# 1. Methods
# 1. JSON

# %% [markdown]
# ## Data lab notebooks

# %% [markdown]
# In the [/Data Lab notebooks/Python/Essentials/Contents](https://bentley.cloud.databricks.com/#notebook/189051)
# notebook you will find links to the remaining notebooks in the _Python Essentials_ folder.
#
# Please work through and understand __all of the notebooks__ linked to from the above Contents notebook.
# We will work through some of these notebooks during class.
#
# Complete the exercises in this notebook.
# All of the code in this notebook and in the notebooks linked to from the above Contents notebook may be asked about in the interviews.

# %% [markdown]
# ## Lists

# %% [markdown]
# __Exercise 1:__
# 1. Create a list that contains all integers greater than or equal to `1` and (strictly) less than `1000000`. Store this list in a varable. Do not display this list.
# 1. Display the last ten elements of this list

# %% [markdown]
# **Interpretation:**
#
# 1) Code:
# - The **range()** function generates the integer numbers between the given start integer to the stop integer,in this case from `1` to `999999`.
# - The **list()** function converts numbers to a list. This result is stored in variable `A`.
# - ``A[-10:]`` use the **index** to select the last ten elements of the list.
# - The **print()** function displays the list.
#
# 2) Output:
# - A list contains integer from 999990 to 999999.

# %%
# %python
A=list(range(1,1000000))
print(A[-10:])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[999990, 999991, 999992, 999993, 999994, 999995, 999996, 999997, 999998, 999999]
# </div>

# %% [markdown]
# __Exercise 2:__ Store a list in variable `b` below so that the cell returns `True`.

# %% [markdown]
# **Interpretation:**
# 1) Code:
# - The **+** (one of the list operators) in python list means to paste the content of multiple lists to a single list.
# - In order to returns **True**, the left side of **==** should be the same as the right side. Therefore, `b` should contain the elements of ``2,'b'``
#
# 2) Output:
# - ['a',1] + b == ['a',1,2,'b'] returns true.

# %%
# %python
b=[2,'b']
['a',1] + b == ['a',1,2,'b']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">19</span><span class="ansired">]: </span>True
# </div>

# %% [markdown]
# __Exercise 3:__ Store a list in variable `c` below so that the cell returns `True`.

# %%
# %python
#Question
c = []
3 * c == [[1,2],[1,2],[1,2]]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">20</span><span class="ansired">]: </span>False
# </div>

# %% [markdown]
# **Interpretation**:
#
# 1) Code:
# - In order to returns **True**, the left side of **==** should be the same as the right side.
# - Multiplying a list `c` by a integer scalar `3`  using ** * ** returns the 3 copies of the list as a result.
# - We know the result and integer scalar, so we can infer the element of the list `c`,which is `[1,2]`.
#
# 2) Output:
# - `c` is a list including one element, which is also a list.
# - 3 * c == [[1,2],[1,2],[1,2]] returns true.

# %%
# %python
#Answer
c = [1,2]
3 * c == [[1,2],[1,2],[1,2]]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>[1, 2, 1, 2, 1, 2]
# </div>

# %% [markdown]
# __Exercise 4:__ Store a list in variable `d` below so that the cell returns `True`.

# %%
# %python
#Question
d = []
d[1:4] == [4,'x',True]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">22</span><span class="ansired">]: </span>False
# </div>

# %% [markdown]
# **Interpretation：**
#
# 1) Code:
# - The right side of operator **==** indicates the second, thrid, and forth elements of the list `d` equal to `4,'x','True'`.
# - To return `True`, the list `d` should include **4,'x',True** at index `1,2,3`
#
# 2) Output:
# - d[1:4] == [4,'x',True] returns true

# %%
# %python
#Question
d = [9,4,'x',True,6]
d[1:4] == [4,'x',True]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">23</span><span class="ansired">]: </span>True
# </div>

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# __Exercise 5:__ create a dictionary with three keys, `a`, `b`, and `c`. The values should be `11`, `22`, and `33` (respectively).

# %% [markdown]
# **Interpretation:**
#
# 1) Code:
# - Dictionaries are collections of _key_-_value_ pairs, which are `'a':11,'b':22,'c':33` in this case, separated by commas and enclosed in braces.
#
# 2) Output:
# - A dictionary with key-value pairs of `'a':11,'b':22,'c':33`

# %%
# %python
dic={'a':11,
     'b':22,
     'c':33}
print(dic)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&apos;a&apos;: 11, &apos;c&apos;: 33, &apos;b&apos;: 22}
# </div>

# %% [markdown]
# The following code cell creates a dictionary and stores it in variable `europe_cities`.

# %%
# %python
#Question
europe_cities = {'spain'  :['madrid', 'barcelona', 'seville', 'valencia'], 
                 'france' :['paris', 'marseille', 'bordeaux'], 
                 'germany':['berlin', 'munich'], 
                 'norway' :['oslo'] }
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# __Exercise 6:__ retrieve the third city in the list of cities in Spain. Do so with a single command. Do not store temporary results in a variable.

# %% [markdown]
# **Interpretation:**
#
# 1) code
# - `europe_cities` is a dictionary, and the values of the dictionary are lists.
# - the key `'spain'` is used to locate the specific item, and  index `2` is used to locate the third element of list.
#
# 2) Output:
# - The third city in the list of cities in Spain in the `europe_cities` dictionary.

# %%
# %python
#Answer
europe_cities = {'spain'  :['madrid', 'barcelona', 'seville', 'valencia'], 
                 'france' :['paris', 'marseille', 'bordeaux'], 
                 'germany':['berlin', 'munich'], 
                 'norway' :['oslo'] }
europe_cities['spain'][2]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">26</span><span class="ansired">]: </span>&apos;seville&apos;
# </div>

# %% [markdown]
# ## Comprehensions

# %% [markdown]
# __Exercise 7:__ use a list comprehension to display a list of the square of every integer greater than or equal to `0` and (strictly) less than `10`.

# %% [markdown]
# **interpretation**
# 1)Code:
# - The **range()** function generates the integer numbers between the given start integer to the stop integer, in this case from ``0`` to ``9``.
# - In the **list comprehension**, **for loop** clause is used to iterate over a sequence of numbers produced by the **range()** function and store it in variable `X`.
# - `X**2` is calculated and the corresponding values are stored in `a_list` as a list
# - The **print()** function display the `a_list`.
#
# 2)Output:
# - A list of squared values of each integer from 0 to 9

# %%
# %python
a_list =[X**2 for X in range(10)]
print(a_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# </div>

# %% [markdown]
# __Exercise 8:__ use a list comprehension to display a list of the square of every odd integer greater than or equal to `0` and (strictly) less than `10`.

# %% [markdown]
# **Interpretation**
# 1) Code:
# - The **range()** function generates the integer numbers between the given start integer to the stop integer, in this case from ``0`` to ``9``.
# - The **if** statement `X %2 !=0` filters the odd numbers produced by the **range()** function.
# - In the list comprehenstion,  **for loop** is used to iterate over each number produced by the **range()** and **if** function   , and store it in variable `X`.
# - Then `X**2` is calculated and the corresponding values are stored in `b_list` as a list
# - The **print()** function display the `b_list`, which is a list.
#
# 2) Output:
# - A list of squared values of each odd integer from 0 to 9

# %%
# %python
b_list=[X**2 for X in range(10) if X %2 !=0]
print(b_list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[1, 9, 25, 49, 81]
# </div>

# %% [markdown]
# The following code cell creates a dictionary and stores it in variable `europe_cities`.

# %%
# %python
#Question
europe_cities = {'spain'  :['madrid', 'barcelona', 'seville', 'valencia'], 
                 'france' :['paris', 'marseille', 'bordeaux'], 
                 'germany':['berlin', 'munich'], 
                 'norway' :['oslo'] }
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# __Exercise 9:__ use a dictionary comprehension to create and display a dictionary with the same keys as `europe_cities` but with values that are the length of the list for that key in the `europe_cities` dictionary. For instance the value corresponding to the key `spain` will be `4`.

# %% [markdown]
# **Interpretation:**
# 1) Code:
# In the dictionary comprehension,
# - **Item()** method changes the key-value pairs stored in dictionary `europe_cities` as tuples;
# -  Tuples are retrieved by **the `for` loop**.
# -  The key and value of the resulting dictionary can be changed so that the **len()** function returns the length of each value retrieved;
# -  New key value pairs ``key:len(value)`` are stored in new dictionary `europe_citiesnew`;
# -  The **print()** function displays the new dictionary `europe_citiesnew`.
#
# 2) Output:
# - It returns a dictionary.
# - The keys of the dictionary are names of the country(original key of the `europe_cities` dinctionary).
# - The values of the dictionary are the length of the list for the corresponding keys. The length indicates the number of the elements that each list contains.

# %%
# %python
europe_cities = {'spain'  :['madrid', 'barcelona', 'seville', 'valencia'], 
                 'france' :['paris', 'marseille', 'bordeaux'], 
                 'germany':['berlin', 'munich'], 
                 'norway' :['oslo'] }
europe_citiesnew={key:len(value) for (key,value) in europe_cities.items()}
print(europe_citiesnew)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&apos;germany&apos;: 2, &apos;spain&apos;: 4, &apos;norway&apos;: 1, &apos;france&apos;: 3}
# </div>

# %% [markdown]
# __Exercise 10:__ Write a list comprehension, in or following the next cell, that returns a list containing the four countries from the dictionary `europe_cap_pop`.

# %%
# %python 
europe_cap_pop = {'spain'  : { 'capital':'madrid' , 'population':46.77 },
                  'france' : { 'capital':'paris'  , 'population':66.03 },
                  'germany': { 'capital':'berlin' , 'population':80.62 },
                  'norway' : { 'capital':'oslo'   , 'population': 5.84 }}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **interpretation:**
#
# 1) Code
# - **europe_cap_pop.keys()** method returns keys of the `europe_cap_pop` dictionary,
# - Using **for loop** we can iterate over a sequence of values produced by the **keys()** method,and store it in variable `x`;
# - `x` is stored in the variable `country2`
# - The **print()** function displays the new list `country2`.
#
# 2) Output
# - A list contains the four countries from the dictionary `europe_cap_pop`.

# %%
# %python
europe_cap_pop = {'spain'  : { 'capital':'madrid' , 'population':46.77 },
                  'france' : { 'capital':'paris'  , 'population':66.03 },
                  'germany': { 'capital':'berlin' , 'population':80.62 },
                  'norway' : { 'capital':'oslo'   , 'population': 5.84 }}

country2 = [x for x in europe_cap_pop.keys()]
print(country2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&apos;germany&apos;, &apos;norway&apos;, &apos;spain&apos;, &apos;france&apos;]
# </div>

# %% [markdown]
# __Exercise 11:__ Write a list comprehension, in or following the next cell, that returns a list containing the four capitals from the dictionary `europe_cap_pop`.

# %%
# %python 
europe_cap_pop = {'spain'  : { 'capital':'madrid' , 'population':46.77 },
                  'france' : { 'capital':'paris'  , 'population':66.03 },
                  'germany': { 'capital':'berlin' , 'population':80.62 },
                  'norway' : { 'capital':'oslo'   , 'population': 5.84 }}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Interpretation:**
# 1) Code
# -  **europe_cap_pop.values()** method returns values of the `europe_cap_pop` dictionary. The values are sub-dictionaries
# - In the list comprehension,  **for loop**  can be used to iterate over a sequence of values produced by the **values()** method,and store it in variable `x`
# -  **x['capital']** indexes the sub-dictionary to obtain the corresponding values;
#
# 2) Output
# - A list contains the four capitals from the dictionary `europe_cap_pop`.

# %%
# %python
captials =[x['capital'] for x in europe_cap_pop.values()]
captials
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">34</span><span class="ansired">]: </span>[&apos;berlin&apos;, &apos;oslo&apos;, &apos;madrid&apos;, &apos;paris&apos;]
# </div>

# %% [markdown]
# ## Map & filter

# %% [markdown]
# __Exercise 12:__ use the `map` function to display a list of the square of every integer greater than or equal to `0` and (strictly) less than `10`.

# %% [markdown]
# **Interpretation:**
#
# 1) code
# - **lambda** creates an anonymous function to store `x**2` in the variable `x`
# - The **range()** function generates the integer numbers between the given start integer to the stop integer, in this case from ``0`` to ``9``
# - **map()** function applies the **lambda** function to the variables returned from **range()** function
# - **list()** function converts iterable value returned by **map()** function to a list
#
# 2) output
# - A list of the square of every integer from `0` to `9`.

# %%
# %python
list(map(lambda x: x**2,
         range(10)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">52</span><span class="ansired">]: </span>[0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# </div>

# %% [markdown]
# __Exercise 13:__ use the `map` and `filter` functions to display a list of the square of every odd integer greater than `0` and (strictly) less than `10`.

# %% [markdown]
# **Interpretation:**
# 1) Code
# - **filter()** function returns only those elements from 0 to 9 for which the **lambda** function `x%2 !=0` returns `True`
# - **map()** function runs the function defined by **lambda** to each elements in `odd`.
# - **list()** function converts iterable value returned by **map()** function to a list
#
# 2) Output
# - A list of the square of every odd integer from `0` to `9`.

# %%
# %python
odd = filter(lambda x: x%2!=0, range(10))
list(map(lambda y: y**2, odd))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">11</span><span class="ansired">]: </span>[1, 9, 25, 49, 81]
# </div>

# %% [markdown]
# __Exercise 14:__ Use the `map` function, in or following the next cell, that returns a list containing the four countries from the dictionary `europe_cap_pop`.

# %%
# %python 
europe_cap_pop = {'spain'  : { 'capital':'madrid' , 'population':46.77 },
                  'france' : { 'capital':'paris'  , 'population':66.03 },
                  'germany': { 'capital':'berlin' , 'population':80.62 },
                  'norway' : { 'capital':'oslo'   , 'population': 5.84 }}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Interpretation:**
# 1) Code
# - **lambda** creates an anonymous function;
# - **map()** function applies the **lambda** function, extracting the values of `keys` from dictionary.
# - **list()** function converts iterable values returned by **map()** function to a list
#
# 2) Output
# - A list contains the four countries from the dictionary `europe_cap_pop`.

# %%
# %python
list(map(lambda key: key, europe_cap_pop))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">55</span><span class="ansired">]: </span>[&apos;norway&apos;, &apos;france&apos;, &apos;spain&apos;, &apos;germany&apos;]
# </div>

# %% [markdown]
# __Exercise 15:__ Use either a list comprehension or the `map` and `filter` functions, in or following the next cell,
# that returns a list containing the capitals of countries with populations over `50` (from the dictionary `europe_cap_pop`).

# %%
# %python 
europe_cap_pop = {'spain'  : { 'capital':'madrid' , 'population':46.77 },
                  'brance' : { 'capital':'paris'  , 'population':66.03 },
                  'germany': { 'capital':'berlin' , 'population':80.62 },
                  'norway' : { 'capital':'oslo'   , 'population': 5.84 }}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Interpretation:**
#
# 1) Code
# - Brackets containing an expression followed by a for clause is used to define list comprehension.
# - The **for** clause access each value from the dictionary `europe_cap_pop`;
# - The expression **x['capital']** access each dictionary value to obtain the corresponding capital;
# - **if** statement is added after **loop** so that only capitals with country populations over 50 will be kept;
#
# 2) Output
#  - A list contains the capitals of countries with populations over `50` (from the dictionary `europe_cap_pop`).

# %%
# %python 
[x['capital'] for x in europe_cap_pop.values() if x['population']>50 ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">42</span><span class="ansired">]: </span>[&apos;berlin&apos;, &apos;paris&apos;]
# </div>

# %% [markdown]
# __The End__
