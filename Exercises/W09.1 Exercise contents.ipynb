# %% [markdown]
# # Week 9 - MA705 Exercise Contents [codingwatchcity] Wed 3:00 LIB 218

# %% [markdown]
# First, clone this notebook to your group `Exercises` folder. Then edit the cloned notebook.
#
# Place your group name
# - in the title of this notebook (in place of `[group name]` in the title)
# - in the title of every exercise notebook linked below (also in place of `[group name]` in the title)
#
# Edit the links below so that they point to __your exercise notebooks__.
#
# Every exercise has three parts:
# 1. The code required to complete the task requested by the exercise.
# 1. The introduction to the code cell that you wrote to complete the exercise.
# 1. The explanation of any output produced by the code cell you wrote to complete the exercise.
#
# Do not remove any of the code or markdown cells that are not part of the exercises. Don't worry about it if you have already done so.

# %% [markdown]
# ## Contents/links
# - [W01.1 Ex. Group Information)](https://bentley.cloud.databricks.com/#notebook/992572)
# - [W02.1.1 Ex. Python(Part 1)](https://bentley.cloud.databricks.com/#notebook/1268530)
# - [W02.1.2 Ex. Python(Part 2)](https://bentley.cloud.databricks.com/#notebook/993421)
# - [W03.1 Ex. pandas](https://bentley.cloud.databricks.com/#notebook/1013806/command/1013807)
# - [W04.1 Ex. Import](https://bentley.cloud.databricks.com/#notebook/1070119/command/1070120)
# - [W05.1 Ex. Table operations](https://bentley.cloud.databricks.com/#notebook/1090838/command/1090839)
# - [W06.2 Ex. Reshape](https://bentley.cloud.databricks.com/#notebook/1135486/command/1135487)
# - [W08.1 Ex. Concatenate](https://bentley.cloud.databricks.com/#notebook/1184531/command/1184532)

# %% [markdown]
# __The End__
